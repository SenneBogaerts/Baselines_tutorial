# %% [markdown]
# <a href="https://colab.research.google.com/github/SenneBogaerts/Baselines_tutorial/blob/main/4_callbacks_hyperparameter_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Baselines3 Tutorial - Callbacks and hyperparameter tuning
#
# Github repo: https://github.com/araffin/rl-tutorial-jnrr19/tree/sb3/
#
# Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentation: https://stable-baselines3.readthedocs.io/en/master/
#
# SB3-Contrib: https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
#
# RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
#
# ## Introduction
#
# In this notebook, you will learn how to use [Callbacks](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html) which allow to do monitoring, auto saving, model manipulation, progress bars, ...
#
#
# You will also see that finding good hyperparameters is key to success in RL.
#
# ## Install Dependencies and Stable Baselines3 Using Pip

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# !apt install swig
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 49 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (523 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 123622 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting stable-baselines3>=2.0.0a4 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading stable_baselines3-2.4.0a10-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.5.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.9.3)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (10.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.32.3)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 12.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.18.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (6.4.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2024.8.30)
# Downloading stable_baselines3-2.4.0a10-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.5/183.5 kB 14.8 MB/s eta 0:00:00
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 61.7 MB/s eta 0:00:00
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.6 MB/s eta 0:00:00
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=a19783f0f85909553c4ce06c1a52427a97ece5c77f5a0f3a0d7ed632f3a6050b
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.3.0 stable-baselines3-2.4.0a10

# %%
import gymnasium as gym
from stable_baselines3 import A2C, SAC, PPO, TD3
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:55: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation

# %% [markdown]
# # The importance of hyperparameter tuning
#
# When compared with Supervised Learning, Deep Reinforcement Learning is far more sensitive to the choice of hyper-parameters such as learning rate, number of neurons, number of layers, optimizer ... etc.
# Poor choice of hyper-parameters can lead to poor/unstable convergence. This challenge is compounded by the variability in performance across random seeds (used to initialize the network weights and the environment).
#
# Here we demonstrate on a toy example the [Soft Actor Critic](https://arxiv.org/abs/1801.01290) algorithm applied in the Pendulum environment. Note the change in performance between the default and "tuned" parameters.

# %%
import numpy as np

from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
eval_env = gym.make("Pendulum-v1")

# %%
default_model = SAC(
    "MlpPolicy",
    "Pendulum-v1",
    verbose=1,
    seed=0,
    batch_size=64,
    policy_kwargs=dict(net_arch=[64, 64]),
).learn(8000)
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 87        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 17.9      |
# |    critic_loss     | 1.25      |
# |    ent_coef        | 0.812     |
# |    ent_coef_loss   | -0.343    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.52e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 84        |
# |    time_elapsed    | 18        |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 44.3      |
# |    critic_loss     | 0.671     |
# |    ent_coef        | 0.646     |
# |    ent_coef_loss   | -0.627    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.53e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 84        |
# |    time_elapsed    | 28        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 69.7      |
# |    critic_loss     | 0.526     |
# |    ent_coef        | 0.517     |
# |    ent_coef_loss   | -0.821    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.42e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 84        |
# |    time_elapsed    | 37        |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 84.3      |
# |    critic_loss     | 3.16      |
# |    ent_coef        | 0.423     |
# |    ent_coef_loss   | -0.699    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 84        |
# |    time_elapsed    | 47        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 103       |
# |    critic_loss     | 2.97      |
# |    ent_coef        | 0.358     |
# |    ent_coef_loss   | -0.475    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 83        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 113       |
# |    critic_loss     | 3.42      |
# |    ent_coef        | 0.304     |
# |    ent_coef_loss   | -0.622    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 4699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 83        |
# |    time_elapsed    | 66        |
# |    total_timesteps | 5600      |
# | train/             |           |
# |    actor_loss      | 138       |
# |    critic_loss     | 1.97      |
# |    ent_coef        | 0.254     |
# |    ent_coef_loss   | -0.973    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 5499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.34e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 84        |
# |    time_elapsed    | 76        |
# |    total_timesteps | 6400      |
# | train/             |           |
# |    actor_loss      | 143       |
# |    critic_loss     | 2.48      |
# |    ent_coef        | 0.207     |
# |    ent_coef_loss   | -0.875    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 6299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 84        |
# |    time_elapsed    | 85        |
# |    total_timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 163       |
# |    critic_loss     | 2.41      |
# |    ent_coef        | 0.175     |
# |    ent_coef_loss   | -0.0117   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.21e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 84        |
# |    time_elapsed    | 94        |
# |    total_timesteps | 8000      |
# | train/             |           |
# |    actor_loss      | 169       |
# |    critic_loss     | 4.44      |
# |    ent_coef        | 0.167     |
# |    ent_coef_loss   | 0.0588    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7899      |
# ----------------------------------

# %%
mean_reward, std_reward = evaluate_policy(default_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-664.17 +/- 94.65

# %%
tuned_model = SAC(
    "MlpPolicy",
    "Pendulum-v1",
    batch_size=256,
    verbose=1,
    policy_kwargs=dict(net_arch=[256, 256]),
    seed=0,
).learn(8000)
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.44e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 93        |
# |    time_elapsed    | 8         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 23.4      |
# |    critic_loss     | 0.237     |
# |    ent_coef        | 0.813     |
# |    ent_coef_loss   | -0.341    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.47e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 91        |
# |    time_elapsed    | 17        |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 47.6      |
# |    critic_loss     | 0.183     |
# |    ent_coef        | 0.647     |
# |    ent_coef_loss   | -0.599    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.34e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 88        |
# |    time_elapsed    | 27        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 64.8      |
# |    critic_loss     | 0.256     |
# |    ent_coef        | 0.531     |
# |    ent_coef_loss   | -0.603    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 86        |
# |    time_elapsed    | 36        |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 74.7      |
# |    critic_loss     | 0.376     |
# |    ent_coef        | 0.452     |
# |    ent_coef_loss   | -0.498    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -975     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 85       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 73       |
# |    critic_loss     | 0.514    |
# |    ent_coef        | 0.389    |
# |    ent_coef_loss   | -0.627   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -829     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 85       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 77       |
# |    critic_loss     | 0.635    |
# |    ent_coef        | 0.327    |
# |    ent_coef_loss   | -0.606   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -737     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 85       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | 68.9     |
# |    critic_loss     | 1.27     |
# |    ent_coef        | 0.269    |
# |    ent_coef_loss   | -0.777   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -660     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 82       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | 76.7     |
# |    critic_loss     | 1.65     |
# |    ent_coef        | 0.219    |
# |    ent_coef_loss   | -0.531   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -601     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 82       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 66.1     |
# |    critic_loss     | 0.778    |
# |    ent_coef        | 0.182    |
# |    ent_coef_loss   | -0.585   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -550     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 82       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 66.3     |
# |    critic_loss     | 1.97     |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -0.522   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------

# %%
mean_reward, std_reward = evaluate_policy(tuned_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-292.26 +/- 313.41

# %% [markdown]
# Exploring hyperparameter tuning is out of the scope (and time schedule) of this tutorial. However, you need to know that we provide tuned hyperparameter in the [rl zoo](https://github.com/DLR-RM/rl-baselines3-zoo) as well as automatic hyperparameter optimization using [Optuna](https://github.com/pfnet/optuna).

# %% [markdown]
# # Callbacks
#
#
# Please read the [documentation](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html). Although Stable-Baselines3 provides you with a callback collection (e.g. for creating checkpoints or for evaluation), we are going to re-implement some so you can get a good understanding of how they work.
#
# To build a custom callback, you need to create a class that derives from `BaseCallback`. This will give you access to events (`_on_training_start`, `_on_step()`) and useful variables (like `self.model` for the RL model).
#
# `_on_step` returns a boolean value for whether or not the training should continue.
#
# Thanks to the access to the models variables, in particular `self.model`, we are able to even change the parameters of the model without halting the training, or changing the model's code.

# %%
from stable_baselines3.common.callbacks import BaseCallback

# %%
class CustomCallback(BaseCallback):
    """
    A custom callback that derives from ``BaseCallback``.

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """

    def __init__(self, verbose=0):
        super().__init__(verbose)
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseRLModel
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env = None  # type: Union[gym.Env, VecEnv, None]
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = None  # type: Dict[str, Any]
        # self.globals = None  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger = None  # type: logger.Logger
        # # Sometimes, for event callback, it is useful
        # # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]

    def _on_training_start(self) -> None:
        """
        This method is called before the first rollout starts.
        """
        pass

    def _on_rollout_start(self) -> None:
        """
        A rollout is the collection of environment interaction
        using the current policy.
        This event is triggered before collecting new samples.
        """
        pass

    def _on_step(self) -> bool:
        """
        This method will be called by the model after each call to `env.step()`.

        For child callback (of an `EventCallback`), this will be called
        when the event is triggered.

        :return: (bool) If the callback returns False, training is aborted early.
        """
        return True

    def _on_rollout_end(self) -> None:
        """
        This event is triggered before updating the policy.
        """
        pass

    def _on_training_end(self) -> None:
        """
        This event is triggered before exiting the `learn()` method.
        """
        pass

# %% [markdown]
# Here we have a simple callback that can only be called twice:

# %%
class SimpleCallback(BaseCallback):
    """
    a simple callback that can only be called twice

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """

    def __init__(self, verbose=0):
        super(SimpleCallback, self).__init__(verbose)
        self._called = False

    def _on_step(self):
        if not self._called:
            print("callback - first call")
            self._called = True
            return True  # returns True, training continues.
        print("callback - second call")
        return False  # returns False, training stops.

# %%
model = SAC("MlpPolicy", "Pendulum-v1", verbose=1)
model.learn(8000, callback=SimpleCallback())
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# callback - first call
# callback - second call

# %% [markdown]
# ## First example: Auto saving best model
# In RL, it is quite useful to keep a clean version of a model as you are training, as we can end up with burn-in of a bad policy. This is a typical use case for callback, as they can call the save function of the model, and observe the training over time.
#
# Using the monitoring wrapper, we can save statistics of the environment, and use them to determine the mean training reward.
# This allows us to save the best model while training.
#
# Note that this is not the proper way of evaluating an RL agent, you should create an test environment and evaluate the agent performance in the callback (cf `EvalCallback`). For simplicity, we will be using the training reward as a proxy.

# %%
import os

import numpy as np

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.results_plotter import load_results, ts2xy

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq, log_dir, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print("Num timesteps: {}".format(self.num_timesteps))
                    print(
                        "Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(
                            self.best_mean_reward, mean_reward
                        )
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print("Saving new best model at {} timesteps".format(x[-1]),flush=True)
                        print("Saving new best model to {}.zip".format(self.save_path),flush=True)
                    self.model.save(self.save_path)

        return True
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env("CartPole-v1", n_envs=1, monitor_dir=log_dir)
# it is equivalent to:
# env = gym.make('CartPole-v1')
# env = Monitor(env, log_dir)
# env = DummyVecEnv([lambda: env])

# Create Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=20, log_dir=log_dir, verbose=1)

model = A2C("MlpPolicy", env, verbose=0)
model.learn(total_timesteps=5000, callback=callback)
# Out:
# Num timesteps: 40
# Best mean reward: -inf - Last mean reward per episode: 35.00
# Saving new best model at 35 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Num timesteps: 60
# Best mean reward: 35.00 - Last mean reward per episode: 28.50
# Num timesteps: 80
# Best mean reward: 35.00 - Last mean reward per episode: 25.33
# Num timesteps: 100
# Best mean reward: 35.00 - Last mean reward per episode: 24.25
# Num timesteps: 120
# Best mean reward: 35.00 - Last mean reward per episode: 24.25
# Num timesteps: 140
# Best mean reward: 35.00 - Last mean reward per episode: 24.25
# Num timesteps: 160
# Best mean reward: 35.00 - Last mean reward per episode: 29.40
# Num timesteps: 180
# Best mean reward: 35.00 - Last mean reward per episode: 27.00
# Num timesteps: 200
# Best mean reward: 35.00 - Last mean reward per episode: 27.00
# Num timesteps: 220
# Best mean reward: 35.00 - Last mean reward per episode: 27.00
# Num timesteps: 240
# Best mean reward: 35.00 - Last mean reward per episode: 27.00
# Num timesteps: 260
# Best mean reward: 35.00 - Last mean reward per episode: 34.86
# Num timesteps: 280
# Best mean reward: 35.00 - Last mean reward per episode: 34.86
# Num timesteps: 300
# Best mean reward: 35.00 - Last mean reward per episode: 34.86
# Num timesteps: 320
# Best mean reward: 35.00 - Last mean reward per episode: 34.86
# Num timesteps: 340
# Best mean reward: 35.00 - Last mean reward per episode: 40.12
# Saving new best model at 321 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 360
# Best mean reward: 40.12 - Last mean reward per episode: 40.12
# Num timesteps: 380
# Best mean reward: 40.12 - Last mean reward per episode: 40.12
# Num timesteps: 400
# Best mean reward: 40.12 - Last mean reward per episode: 40.12
# Num timesteps: 420
# Best mean reward: 40.12 - Last mean reward per episode: 40.12
# Num timesteps: 440
# Best mean reward: 40.12 - Last mean reward per episode: 47.89
# Saving new best model at 431 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 460
# Best mean reward: 47.89 - Last mean reward per episode: 47.89
# Num timesteps: 480
# Best mean reward: 47.89 - Last mean reward per episode: 47.89
# Num timesteps: 500
# Best mean reward: 47.89 - Last mean reward per episode: 47.89
# Num timesteps: 520
# Best mean reward: 47.89 - Last mean reward per episode: 47.89
# Num timesteps: 540
# Best mean reward: 47.89 - Last mean reward per episode: 47.89
# Num timesteps: 560
# Best mean reward: 47.89 - Last mean reward per episode: 54.40
# Saving new best model at 544 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 580
# Best mean reward: 54.40 - Last mean reward per episode: 54.40
# Num timesteps: 600
# Best mean reward: 54.40 - Last mean reward per episode: 53.18
# Num timesteps: 620
# Best mean reward: 54.40 - Last mean reward per episode: 50.67
# Num timesteps: 640
# Best mean reward: 54.40 - Last mean reward per episode: 50.67
# Num timesteps: 660
# Best mean reward: 54.40 - Last mean reward per episode: 49.69
# Num timesteps: 680
# Best mean reward: 54.40 - Last mean reward per episode: 49.69
# Num timesteps: 700
# Best mean reward: 54.40 - Last mean reward per episode: 49.29
# Num timesteps: 720
# Best mean reward: 54.40 - Last mean reward per episode: 49.29
# Num timesteps: 740
# Best mean reward: 54.40 - Last mean reward per episode: 49.00
# Num timesteps: 760
# Best mean reward: 54.40 - Last mean reward per episode: 47.31
# Num timesteps: 780
# Best mean reward: 54.40 - Last mean reward per episode: 47.31
# Num timesteps: 800
# Best mean reward: 54.40 - Last mean reward per episode: 46.94
# Num timesteps: 820
# Best mean reward: 54.40 - Last mean reward per episode: 46.94
# Num timesteps: 840
# Best mean reward: 54.40 - Last mean reward per episode: 45.67
# Num timesteps: 860
# Best mean reward: 54.40 - Last mean reward per episode: 44.47
# Num timesteps: 880
# Best mean reward: 54.40 - Last mean reward per episode: 43.65
# Num timesteps: 900
# Best mean reward: 54.40 - Last mean reward per episode: 42.48
# Num timesteps: 920
# Best mean reward: 54.40 - Last mean reward per episode: 42.48
# Num timesteps: 940
# Best mean reward: 54.40 - Last mean reward per episode: 42.64
# Num timesteps: 960
# Best mean reward: 54.40 - Last mean reward per episode: 42.64
# Num timesteps: 980
# Best mean reward: 54.40 - Last mean reward per episode: 42.64
# Num timesteps: 1000
# Best mean reward: 54.40 - Last mean reward per episode: 43.09
# Num timesteps: 1020
# Best mean reward: 54.40 - Last mean reward per episode: 42.08
# Num timesteps: 1040
# Best mean reward: 54.40 - Last mean reward per episode: 41.44
# Num timesteps: 1060
# Best mean reward: 54.40 - Last mean reward per episode: 41.44
# Num timesteps: 1080
# Best mean reward: 54.40 - Last mean reward per episode: 41.27
# Num timesteps: 1100
# Best mean reward: 54.40 - Last mean reward per episode: 41.27
# Num timesteps: 1120
# Best mean reward: 54.40 - Last mean reward per episode: 40.78
# Num timesteps: 1140
# Best mean reward: 54.40 - Last mean reward per episode: 40.21
# Num timesteps: 1160
# Best mean reward: 54.40 - Last mean reward per episode: 39.83
# Num timesteps: 1180
# Best mean reward: 54.40 - Last mean reward per episode: 39.83
# Num timesteps: 1200
# Best mean reward: 54.40 - Last mean reward per episode: 39.83
# Num timesteps: 1220
# Best mean reward: 54.40 - Last mean reward per episode: 40.30
# Num timesteps: 1240
# Best mean reward: 54.40 - Last mean reward per episode: 40.30
# Num timesteps: 1260
# Best mean reward: 54.40 - Last mean reward per episode: 40.26
# Num timesteps: 1280
# Best mean reward: 54.40 - Last mean reward per episode: 39.91
# Num timesteps: 1300
# Best mean reward: 54.40 - Last mean reward per episode: 39.91
# Num timesteps: 1320
# Best mean reward: 54.40 - Last mean reward per episode: 39.91
# Num timesteps: 1340
# Best mean reward: 54.40 - Last mean reward per episode: 39.91
# Num timesteps: 1360
# Best mean reward: 54.40 - Last mean reward per episode: 40.70
# Num timesteps: 1380
# Best mean reward: 54.40 - Last mean reward per episode: 40.70
# Num timesteps: 1400
# Best mean reward: 54.40 - Last mean reward per episode: 40.70
# Num timesteps: 1420
# Best mean reward: 54.40 - Last mean reward per episode: 41.26
# Num timesteps: 1440
# Best mean reward: 54.40 - Last mean reward per episode: 41.26
# Num timesteps: 1460
# Best mean reward: 54.40 - Last mean reward per episode: 41.26
# Num timesteps: 1480
# Best mean reward: 54.40 - Last mean reward per episode: 41.26
# Num timesteps: 1500
# Best mean reward: 54.40 - Last mean reward per episode: 42.60
# Num timesteps: 1520
# Best mean reward: 54.40 - Last mean reward per episode: 42.60
# Num timesteps: 1540
# Best mean reward: 54.40 - Last mean reward per episode: 42.60
# Num timesteps: 1560
# Best mean reward: 54.40 - Last mean reward per episode: 42.60
# Num timesteps: 1580
# Best mean reward: 54.40 - Last mean reward per episode: 42.60
# Num timesteps: 1600
# Best mean reward: 54.40 - Last mean reward per episode: 44.17
# Num timesteps: 1620
# Best mean reward: 54.40 - Last mean reward per episode: 44.17
# Num timesteps: 1640
# Best mean reward: 54.40 - Last mean reward per episode: 44.17
# Num timesteps: 1660
# Best mean reward: 54.40 - Last mean reward per episode: 44.46
# Num timesteps: 1680
# Best mean reward: 54.40 - Last mean reward per episode: 44.46
# Num timesteps: 1700
# Best mean reward: 54.40 - Last mean reward per episode: 44.46
# Num timesteps: 1720
# Best mean reward: 54.40 - Last mean reward per episode: 44.46
# Num timesteps: 1740
# Best mean reward: 54.40 - Last mean reward per episode: 45.45
# Num timesteps: 1760
# Best mean reward: 54.40 - Last mean reward per episode: 45.45
# Num timesteps: 1780
# Best mean reward: 54.40 - Last mean reward per episode: 45.18
# Num timesteps: 1800
# Best mean reward: 54.40 - Last mean reward per episode: 44.55
# Num timesteps: 1820
# Best mean reward: 54.40 - Last mean reward per episode: 44.39
# Num timesteps: 1840
# Best mean reward: 54.40 - Last mean reward per episode: 44.39
# Num timesteps: 1860
# Best mean reward: 54.40 - Last mean reward per episode: 43.95
# Num timesteps: 1880
# Best mean reward: 54.40 - Last mean reward per episode: 43.95
# Num timesteps: 1900
# Best mean reward: 54.40 - Last mean reward per episode: 43.95
# Num timesteps: 1920
# Best mean reward: 54.40 - Last mean reward per episode: 44.23
# Num timesteps: 1940
# Best mean reward: 54.40 - Last mean reward per episode: 44.23
# Num timesteps: 1960
# Best mean reward: 54.40 - Last mean reward per episode: 44.30
# Num timesteps: 1980
# Best mean reward: 54.40 - Last mean reward per episode: 44.30
# Num timesteps: 2000
# Best mean reward: 54.40 - Last mean reward per episode: 44.30
# Num timesteps: 2020
# Best mean reward: 54.40 - Last mean reward per episode: 44.30
# Num timesteps: 2040
# Best mean reward: 54.40 - Last mean reward per episode: 45.00
# Num timesteps: 2060
# Best mean reward: 54.40 - Last mean reward per episode: 45.00
# Num timesteps: 2080
# Best mean reward: 54.40 - Last mean reward per episode: 45.22
# Num timesteps: 2100
# Best mean reward: 54.40 - Last mean reward per episode: 45.22
# Num timesteps: 2120
# Best mean reward: 54.40 - Last mean reward per episode: 45.22
# Num timesteps: 2140
# Best mean reward: 54.40 - Last mean reward per episode: 45.22
# Num timesteps: 2160
# Best mean reward: 54.40 - Last mean reward per episode: 45.22
# Num timesteps: 2180
# Best mean reward: 54.40 - Last mean reward per episode: 45.22
# Num timesteps: 2200
# Best mean reward: 54.40 - Last mean reward per episode: 46.49
# Num timesteps: 2220
# Best mean reward: 54.40 - Last mean reward per episode: 46.49
# Num timesteps: 2240
# Best mean reward: 54.40 - Last mean reward per episode: 46.50
# Num timesteps: 2260
# Best mean reward: 54.40 - Last mean reward per episode: 46.50
# Num timesteps: 2280
# Best mean reward: 54.40 - Last mean reward per episode: 46.50
# Num timesteps: 2300
# Best mean reward: 54.40 - Last mean reward per episode: 46.67
# Num timesteps: 2320
# Best mean reward: 54.40 - Last mean reward per episode: 46.67
# Num timesteps: 2340
# Best mean reward: 54.40 - Last mean reward per episode: 46.67
# Num timesteps: 2360
# Best mean reward: 54.40 - Last mean reward per episode: 46.67
# Num timesteps: 2380
# Best mean reward: 54.40 - Last mean reward per episode: 47.38
# Num timesteps: 2400
# Best mean reward: 54.40 - Last mean reward per episode: 47.38
# Num timesteps: 2420
# Best mean reward: 54.40 - Last mean reward per episode: 47.38
# Num timesteps: 2440
# Best mean reward: 54.40 - Last mean reward per episode: 47.38
# Num timesteps: 2460
# Best mean reward: 54.40 - Last mean reward per episode: 47.98
# Num timesteps: 2480
# Best mean reward: 54.40 - Last mean reward per episode: 47.98
# Num timesteps: 2500
# Best mean reward: 54.40 - Last mean reward per episode: 48.06
# Num timesteps: 2520
# Best mean reward: 54.40 - Last mean reward per episode: 48.06
# Num timesteps: 2540
# Best mean reward: 54.40 - Last mean reward per episode: 47.66
# Num timesteps: 2560
# Best mean reward: 54.40 - Last mean reward per episode: 47.66
# Num timesteps: 2580
# Best mean reward: 54.40 - Last mean reward per episode: 47.46
# Num timesteps: 2600
# Best mean reward: 54.40 - Last mean reward per episode: 47.46
# Num timesteps: 2620
# Best mean reward: 54.40 - Last mean reward per episode: 47.46
# Num timesteps: 2640
# Best mean reward: 54.40 - Last mean reward per episode: 47.73
# Num timesteps: 2660
# Best mean reward: 54.40 - Last mean reward per episode: 47.73
# Num timesteps: 2680
# Best mean reward: 54.40 - Last mean reward per episode: 47.73
# Num timesteps: 2700
# Best mean reward: 54.40 - Last mean reward per episode: 48.00
# Num timesteps: 2720
# Best mean reward: 54.40 - Last mean reward per episode: 48.00
# Num timesteps: 2740
# Best mean reward: 54.40 - Last mean reward per episode: 48.00
# Num timesteps: 2760
# Best mean reward: 54.40 - Last mean reward per episode: 48.18
# Num timesteps: 2780
# Best mean reward: 54.40 - Last mean reward per episode: 48.18
# Num timesteps: 2800
# Best mean reward: 54.40 - Last mean reward per episode: 48.28
# Num timesteps: 2820
# Best mean reward: 54.40 - Last mean reward per episode: 48.28
# Num timesteps: 2840
# Best mean reward: 54.40 - Last mean reward per episode: 48.28
# Num timesteps: 2860
# Best mean reward: 54.40 - Last mean reward per episode: 48.28
# Num timesteps: 2880
# Best mean reward: 54.40 - Last mean reward per episode: 48.28
# Num timesteps: 2900
# Best mean reward: 54.40 - Last mean reward per episode: 48.92
# Num timesteps: 2920
# Best mean reward: 54.40 - Last mean reward per episode: 48.92
# Num timesteps: 2940
# Best mean reward: 54.40 - Last mean reward per episode: 48.92
# Num timesteps: 2960
# Best mean reward: 54.40 - Last mean reward per episode: 49.07
# Num timesteps: 2980
# Best mean reward: 54.40 - Last mean reward per episode: 49.07
# Num timesteps: 3000
# Best mean reward: 54.40 - Last mean reward per episode: 49.07
# Num timesteps: 3020
# Best mean reward: 54.40 - Last mean reward per episode: 49.07
# Num timesteps: 3040
# Best mean reward: 54.40 - Last mean reward per episode: 49.07
# Num timesteps: 3060
# Best mean reward: 54.40 - Last mean reward per episode: 49.07
# Num timesteps: 3080
# Best mean reward: 54.40 - Last mean reward per episode: 49.07
# Num timesteps: 3100
# Best mean reward: 54.40 - Last mean reward per episode: 50.56
# Num timesteps: 3120
# Best mean reward: 54.40 - Last mean reward per episode: 50.56
# Num timesteps: 3140
# Best mean reward: 54.40 - Last mean reward per episode: 50.56
# Num timesteps: 3160
# Best mean reward: 54.40 - Last mean reward per episode: 50.56
# Num timesteps: 3180
# Best mean reward: 54.40 - Last mean reward per episode: 51.27
# Num timesteps: 3200
# Best mean reward: 54.40 - Last mean reward per episode: 51.27
# Num timesteps: 3220
# Best mean reward: 54.40 - Last mean reward per episode: 51.27
# Num timesteps: 3240
# Best mean reward: 54.40 - Last mean reward per episode: 51.27
# Num timesteps: 3260
# Best mean reward: 54.40 - Last mean reward per episode: 51.27
# Num timesteps: 3280
# Best mean reward: 54.40 - Last mean reward per episode: 52.05
# Num timesteps: 3300
# Best mean reward: 54.40 - Last mean reward per episode: 52.05
# Num timesteps: 3320
# Best mean reward: 54.40 - Last mean reward per episode: 52.05
# Num timesteps: 3340
# Best mean reward: 54.40 - Last mean reward per episode: 52.14
# Num timesteps: 3360
# Best mean reward: 54.40 - Last mean reward per episode: 52.14
# Num timesteps: 3380
# Best mean reward: 54.40 - Last mean reward per episode: 51.98
# Num timesteps: 3400
# Best mean reward: 54.40 - Last mean reward per episode: 51.98
# Num timesteps: 3420
# Best mean reward: 54.40 - Last mean reward per episode: 51.98
# Num timesteps: 3440
# Best mean reward: 54.40 - Last mean reward per episode: 51.98
# Num timesteps: 3460
# Best mean reward: 54.40 - Last mean reward per episode: 52.29
# Num timesteps: 3480
# Best mean reward: 54.40 - Last mean reward per episode: 52.29
# Num timesteps: 3500
# Best mean reward: 54.40 - Last mean reward per episode: 52.29
# Num timesteps: 3520
# Best mean reward: 54.40 - Last mean reward per episode: 52.40
# Num timesteps: 3540
# Best mean reward: 54.40 - Last mean reward per episode: 52.40
# Num timesteps: 3560
# Best mean reward: 54.40 - Last mean reward per episode: 52.15
# Num timesteps: 3580
# Best mean reward: 54.40 - Last mean reward per episode: 52.15
# Num timesteps: 3600
# Best mean reward: 54.40 - Last mean reward per episode: 52.12
# Num timesteps: 3620
# Best mean reward: 54.40 - Last mean reward per episode: 52.12
# Num timesteps: 3640
# Best mean reward: 54.40 - Last mean reward per episode: 52.12
# Num timesteps: 3660
# Best mean reward: 54.40 - Last mean reward per episode: 52.01
# Num timesteps: 3680
# Best mean reward: 54.40 - Last mean reward per episode: 52.01
# Num timesteps: 3700
# Best mean reward: 54.40 - Last mean reward per episode: 51.92
# Num timesteps: 3720
# Best mean reward: 54.40 - Last mean reward per episode: 51.53
# Num timesteps: 3740
# Best mean reward: 54.40 - Last mean reward per episode: 51.53
# Num timesteps: 3760
# Best mean reward: 54.40 - Last mean reward per episode: 51.25
# Num timesteps: 3780
# Best mean reward: 54.40 - Last mean reward per episode: 51.25
# Num timesteps: 3800
# Best mean reward: 54.40 - Last mean reward per episode: 51.28
# Num timesteps: 3820
# Best mean reward: 54.40 - Last mean reward per episode: 51.28
# Num timesteps: 3840
# Best mean reward: 54.40 - Last mean reward per episode: 51.28
# Num timesteps: 3860
# Best mean reward: 54.40 - Last mean reward per episode: 51.28
# Num timesteps: 3880
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 3900
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 3920
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 3940
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 3960
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 3980
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 4000
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 4020
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 4040
# Best mean reward: 54.40 - Last mean reward per episode: 51.67
# Num timesteps: 4060
# Best mean reward: 54.40 - Last mean reward per episode: 53.17
# Num timesteps: 4080
# Best mean reward: 54.40 - Last mean reward per episode: 53.17
# Num timesteps: 4100
# Best mean reward: 54.40 - Last mean reward per episode: 53.17
# Num timesteps: 4120
# Best mean reward: 54.40 - Last mean reward per episode: 53.44
# Num timesteps: 4140
# Best mean reward: 54.40 - Last mean reward per episode: 53.44
# Num timesteps: 4160
# Best mean reward: 54.40 - Last mean reward per episode: 53.44
# Num timesteps: 4180
# Best mean reward: 54.40 - Last mean reward per episode: 53.44
# Num timesteps: 4200
# Best mean reward: 54.40 - Last mean reward per episode: 53.44
# Num timesteps: 4220
# Best mean reward: 54.40 - Last mean reward per episode: 53.44
# Num timesteps: 4240
# Best mean reward: 54.40 - Last mean reward per episode: 53.44
# Num timesteps: 4260
# Best mean reward: 54.40 - Last mean reward per episode: 54.55
# Saving new best model at 4255 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4280
# Best mean reward: 54.55 - Last mean reward per episode: 54.55
# Num timesteps: 4300
# Best mean reward: 54.55 - Last mean reward per episode: 54.55
# Num timesteps: 4320
# Best mean reward: 54.55 - Last mean reward per episode: 54.55
# Num timesteps: 4340
# Best mean reward: 54.55 - Last mean reward per episode: 54.55
# Num timesteps: 4360
# Best mean reward: 54.55 - Last mean reward per episode: 54.96
# Saving new best model at 4342 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4380
# Best mean reward: 54.96 - Last mean reward per episode: 54.96
# Num timesteps: 4400
# Best mean reward: 54.96 - Last mean reward per episode: 54.96
# Num timesteps: 4420
# Best mean reward: 54.96 - Last mean reward per episode: 54.96
# Num timesteps: 4440
# Best mean reward: 54.96 - Last mean reward per episode: 55.36
# Saving new best model at 4429 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4460
# Best mean reward: 55.36 - Last mean reward per episode: 55.36
# Num timesteps: 4480
# Best mean reward: 55.36 - Last mean reward per episode: 55.36
# Num timesteps: 4500
# Best mean reward: 55.36 - Last mean reward per episode: 55.36
# Num timesteps: 4520
# Best mean reward: 55.36 - Last mean reward per episode: 55.36
# Num timesteps: 4540
# Best mean reward: 55.36 - Last mean reward per episode: 55.94
# Saving new best model at 4531 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4560
# Best mean reward: 55.94 - Last mean reward per episode: 55.94
# Num timesteps: 4580
# Best mean reward: 55.94 - Last mean reward per episode: 55.94
# Num timesteps: 4600
# Best mean reward: 55.94 - Last mean reward per episode: 55.94
# Num timesteps: 4620
# Best mean reward: 55.94 - Last mean reward per episode: 55.94
# Num timesteps: 4640
# Best mean reward: 55.94 - Last mean reward per episode: 55.94
# Num timesteps: 4660
# Best mean reward: 55.94 - Last mean reward per episode: 55.94
# Num timesteps: 4680
# Best mean reward: 55.94 - Last mean reward per episode: 57.07
# Saving new best model at 4680 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4700
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4720
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4740
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4760
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4780
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4800
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4820
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4840
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4860
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4880
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4900
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4920
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4940
# Best mean reward: 57.07 - Last mean reward per episode: 57.07
# Num timesteps: 4960
# Best mean reward: 57.07 - Last mean reward per episode: 59.73
# Saving new best model at 4958 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4980
# Best mean reward: 59.73 - Last mean reward per episode: 59.73
# Num timesteps: 5000
# Best mean reward: 59.73 - Last mean reward per episode: 59.32

# %% [markdown]
# ## Second example: Realtime plotting of performance
# While training, it is sometimes useful to how the training progresses over time, relative to the episodic reward.
# For this, Stable-Baselines has [Tensorboard support](https://stable-baselines.readthedocs.io/en/master/guide/tensorboard.html), however this can be very combersome, especially in disk space usage.
#
# **NOTE: Unfortunately live plotting does not work out of the box on google colab**
#
# Here, we can use callback again, to plot the episodic reward in realtime, using the monitoring wrapper:

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook


class PlottingCallback(BaseCallback):
    """
    Callback for plotting the performance in realtime.

    :param verbose: (int)
    """
    def __init__(self, verbose=1):
        super().__init__(verbose)
        self._plot = None

    def _on_step(self) -> bool:
        # get the monitor's data
        x, y = ts2xy(load_results(log_dir), 'timesteps')
        if self._plot is None: # make the plot
            plt.ion()
            fig = plt.figure(figsize=(6,3))
            ax = fig.add_subplot(111)
            line, = ax.plot(x, y)
            self._plot = (line, ax, fig)
            plt.show()
        else: # update and rescale the plot
            self._plot[0].set_data(x, y)
            self._plot[-2].relim()
            self._plot[-2].set_xlim([self.locals["total_timesteps"] * -0.02,
                                    self.locals["total_timesteps"] * 1.02])
            self._plot[-2].autoscale_view(True,True,True)
            self._plot[-1].canvas.draw()

# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('MountainCarContinuous-v0', n_envs=1, monitor_dir=log_dir)

plotting_callback = PlottingCallback()

model = PPO('MlpPolicy', env, verbose=0)
model.learn(10000, callback=plotting_callback)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# <div id='3e2844f4-8633-4aa4-b246-06a4341e12de'></div>

# %% [markdown]
# ## Third example: Progress bar
# Quality of life improvement are always welcome when developping and using RL. Here, we used [tqdm](https://tqdm.github.io/) to show a progress bar of the training, along with number of timesteps per second and the estimated time remaining to the end of the training:
#
# Please note that this callback is already included in SB3 and can be used by passing `progress_bar=True` to the `learn()` method.

# %%
from tqdm.auto import tqdm


class ProgressBarCallback(BaseCallback):
    """
    :param pbar: (tqdm.pbar) Progress bar object
    """

    def __init__(self, pbar):
        super().__init__()
        self._pbar = pbar

    def _on_step(self):
        # Update the progress bar:
        self._pbar.n = self.num_timesteps
        self._pbar.update(0)


# this callback uses the 'with' block, allowing for correct initialisation and destruction
class ProgressBarManager(object):
    def __init__(self, total_timesteps):  # init object with total timesteps
        self.pbar = None
        self.total_timesteps = total_timesteps

    def __enter__(self):  # create the progress bar and callback, return the callback
        self.pbar = tqdm(total=self.total_timesteps)

        return ProgressBarCallback(self.pbar)

    def __exit__(self, exc_type, exc_val, exc_tb):  # close the callback
        self.pbar.n = self.total_timesteps
        self.pbar.update(0)
        self.pbar.close()


model = TD3("MlpPolicy", "Pendulum-v1", verbose=0)
# Using a context manager garanties that the tqdm progress bar closes correctly
with ProgressBarManager(2000) as callback:
    model.learn(2000, callback=callback)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# ## Forth example: Composition
# Thanks to the functional nature of callbacks, it is possible to do a composition of callbacks, into a single callback. This means we can auto save our best model, show the progress bar and episodic reward of the training.
#
# The callbacks are automatically composed when you pass a list to the `learn()` method. Under the hood, a `CallbackList` is created.

# %%
from stable_baselines3.common.callbacks import CallbackList

# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('CartPole-v1', n_envs=1, monitor_dir=log_dir)

# Create callbacks
auto_save_callback = SaveOnBestTrainingRewardCallback(check_freq=100, log_dir=log_dir,verbose=1)

model = PPO('MlpPolicy', env, verbose=0)
with ProgressBarManager(1000) as progress_callback:
  # This is equivalent to callback=CallbackList([progress_callback, auto_save_callback])
  model.learn(1000, callback=CallbackList([progress_callback, auto_save_callback]))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## Exercise: Code your own callback
#
#
# The previous examples showed the basics of what is a callback and what you do with it.
#
# The goal of this exercise is to create a callback that will evaluate the model using a test environment and save it if this is the best known model.
#
# To make things easier, we are going to use a class instead of a function with the magic method `__call__`.

# %%
class EvalCallback(BaseCallback):
    """
    Callback for evaluating an agent.

    :param eval_env: (gym.Env) The environment used for initialization
    :param n_eval_episodes: (int) The number of episodes to test the agent
    :param eval_freq: (int) Evaluate the agent every eval_freq call of the callback.
    """

    def __init__(self, eval_env, n_eval_episodes=5, eval_freq=20):
        super().__init__()
        self.eval_env = eval_env
        self.n_eval_episodes = n_eval_episodes
        self.eval_freq = eval_freq
        self.best_mean_reward = -np.inf

    def _on_step(self):
        """
        This method will be called by the model.

        :return: (bool)
        """

        # self.n_calls is automatically updated because
        # we derive from BaseCallback
        if self.n_calls % self.eval_freq == 0:
            # === YOUR CODE HERE ===#
            # Evaluate the agent:
            # you need to do self.n_eval_episodes loop using self.eval_env
            # hint: you can use self.model.predict(obs, deterministic=True)

            # Save the agent if needed
            # and update self.best_mean_reward

            print("Best mean reward: {:.2f}".format(self.best_mean_reward))

            # ====================== #
        return True

# %% [markdown]
# ### Test your callback

# %%
# Env used for training
env = gym.make("CartPole-v1")
# Env for evaluating the agent
eval_env = gym.make("CartPole-v1")

# === YOUR CODE HERE ===#
# Create the callback object
callback = None

# Create the RL model
model = None

# ====================== #

# Train the RL model
model.learn(int(100000), callback=callback)

# %% [markdown]
# # Conclusion
#
#
# In this notebook we have seen:
# - that good hyperparameters are key to the success of RL, you should not except the default ones to work on every problems
# - what is a callback and what you can do with it
# - how to create your own callback
